# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

import joblib

# %%
df = pd.read_csv("diabetes_prediction_dataset (1).csv")

df
# Out:
#       age  gender   bmi  hypertension  heart_disease  smoking_history  \
# 0      69       1  25.6             0              0                2
# 1      32       0  23.5             0              0                3
# 2      78       0  27.4             1              1                1
# 3      38       1  31.7             0              0                1
# 4      41       0  27.8             0              1                3
# ...   ...     ...   ...           ...            ...              ...
# 4995   37       0  33.2             1              0                0
# 4996   81       0  34.4             0              0                1
# 4997   33       0  27.5             0              1                2
# 4998   68       1  32.1             0              1                3
# 4999   54       0  21.5             0              0                3
#
#       physical_activity_level  alcohol_intake  diet_score  sleep_hours  ...  \
# 0                           5               2           3          5.6  ...
# 1                           7               1           8          9.8  ...
# 2                           8               2           5          8.6  ...
# 3                           3               0           1          8.3  ...
# 4                           0               2           9          7.0  ...
# ...                       ...             ...         ...          ...  ...
# 4995                        7               0           5          7.0  ...
# 4996                        4               0           3          7.6  ...
# 4997                        7               2           6          5.6  ...
# 4998                        0               2           8          4.4  ...
# 4999                        8               4           2          6.5  ...
#
#       waist_circumference  family_history  exercise_frequency  \
# 0                    99.5               1                   5
# 1                   101.0               1                   6
# 2                    97.9               0                   1
# 3                    87.6               1                   6
# 4                    96.2               1                   1
# ...                   ...             ...                 ...
# 4995                106.5               0                   0
# 4996                106.4               0                   2
# 4997                 68.8               0                   5
# 4998                 83.1               0                   4
# 4999                 88.2               1                   6
#
#       fasting_blood_sugar  hba1c  skin_thickness  pregnancies  income_level  \
# 0                    65.2    5.5            19.1            1             2
# 1                   117.2    4.7            11.8            0             4
# 2                   120.2    6.4            15.7            3             2
# 3                   114.0    6.3            31.9            5             2
# 4                   129.1    7.1            24.0            5             3
# ...                   ...    ...             ...          ...           ...
# 4995                137.5    6.0            18.0            3             3
# 4996                 74.9    6.1            -3.1            5             2
# 4997                111.0    4.5            23.0            2             1
# 4998                 90.3    5.8            16.2            2             4
# 4999                128.7    6.4             7.9            3             2
#
#       region  diabetes
# 0          2         0
# 1          2         0
# 2          2         0
# 3          0         0
# 4          0         0
# ...      ...       ...
# 4995       0         0
# 4996       3         0
# 4997       2         0
# 4998       3         0
# 4999       0         0
#
# [5000 rows x 27 columns]

# %%
df.head()
# Out:
#    age  gender   bmi  hypertension  heart_disease  smoking_history  \
# 0   69       1  25.6             0              0                2
# 1   32       0  23.5             0              0                3
# 2   78       0  27.4             1              1                1
# 3   38       1  31.7             0              0                1
# 4   41       0  27.8             0              1                3
#
#    physical_activity_level  alcohol_intake  diet_score  sleep_hours  ...  \
# 0                        5               2           3          5.6  ...
# 1                        7               1           8          9.8  ...
# 2                        8               2           5          8.6  ...
# 3                        3               0           1          8.3  ...
# 4                        0               2           9          7.0  ...
#
#    waist_circumference  family_history  exercise_frequency  \
# 0                 99.5               1                   5
# 1                101.0               1                   6
# 2                 97.9               0                   1
# 3                 87.6               1                   6
# 4                 96.2               1                   1
#
#    fasting_blood_sugar  hba1c  skin_thickness  pregnancies  income_level  \
# 0                 65.2    5.5            19.1            1             2
# 1                117.2    4.7            11.8            0             4
# 2                120.2    6.4            15.7            3             2
# 3                114.0    6.3            31.9            5             2
# 4                129.1    7.1            24.0            5             3
#
#    region  diabetes
# 0       2         0
# 1       2         0
# 2       2         0
# 3       0         0
# 4       0         0
#
# [5 rows x 27 columns]

# %%
print(df.shape)
# Out:
# (5000, 27)

# %%
print(df.columns)
# Out:
# Index(['age', 'gender', 'bmi', 'hypertension', 'heart_disease',
#        'smoking_history', 'physical_activity_level', 'alcohol_intake',
#        'diet_score', 'sleep_hours', 'stress_level', 'glucose_level',
#        'blood_pressure_systolic', 'blood_pressure_diastolic', 'insulin_level',
#        'cholesterol', 'triglycerides', 'waist_circumference', 'family_history',
#        'exercise_frequency', 'fasting_blood_sugar', 'hba1c', 'skin_thickness',
#        'pregnancies', 'income_level', 'region', 'diabetes'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       5000 non-null   int64
#  1   gender                    5000 non-null   int64
#  2   bmi                       5000 non-null   float64
#  3   hypertension              5000 non-null   int64
#  4   heart_disease             5000 non-null   int64
#  5   smoking_history           5000 non-null   int64
#  6   physical_activity_level   5000 non-null   int64
#  7   alcohol_intake            5000 non-null   int64
#  8   diet_score                5000 non-null   int64
#  9   sleep_hours               5000 non-null   float64
#  10  stress_level              5000 non-null   int64
#  11  glucose_level             5000 non-null   float64
#  12  blood_pressure_systolic   5000 non-null   float64
#  13  blood_pressure_diastolic  5000 non-null   float64
#  14  insulin_level             5000 non-null   float64
#  15  cholesterol               5000 non-null   float64
#  16  triglycerides             5000 non-null   float64
#  17  waist_circumference       5000 non-null   float64
#  18  family_history            5000 non-null   int64
#  19  exercise_frequency        5000 non-null   int64
#  20  fasting_blood_sugar       5000 non-null   float64
#  21  hba1c                     5000 non-null   float64
#  22  skin_thickness            5000 non-null   float64
#  23  pregnancies               5000 non-null   int64
#  24  income_level              5000 non-null   int64
#  25  region                    5000 non-null   int64
#  26  diabetes                  5000 non-null   int64
# dtypes: float64(12), int64(15)
# memory usage: 1.0 MB
# None

# %%
print(df.isnull().sum())
# Out:
# age                         0
# gender                      0
# bmi                         0
# hypertension                0
# heart_disease               0
# smoking_history             0
# physical_activity_level     0
# alcohol_intake              0
# diet_score                  0
# sleep_hours                 0
# stress_level                0
# glucose_level               0
# blood_pressure_systolic     0
# blood_pressure_diastolic    0
# insulin_level               0
# cholesterol                 0
# triglycerides               0
# waist_circumference         0
# family_history              0
# exercise_frequency          0
# fasting_blood_sugar         0
# hba1c                       0
# skin_thickness              0
# pregnancies                 0
# income_level                0
# region                      0
# diabetes                    0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
df["diabetes"].value_counts()
# Out:
# diabetes
# 0    3522
# 1    1478
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X = df.drop("diabetes", axis=1)
y = df["diabetes"]
scaler=StandardScaler()
x_scaled=scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2,stratify=y)

# %%
model = RandomForestClassifier(
    n_estimators=200,
    max_depth=20,
    class_weight="balanced",
    random_state=42
)
y_pred=model.fit(X_train,y_train)
y_pred
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=20, n_estimators=200,
#                        random_state=42)

# %%
from sklearn.metrics import classification_report

#print(classification_report(y_test, model.predict(X_test)))

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,recall_score

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
#print('Recall',recall_score(y_test,y_pred))
# Out:
# Accuracy: 0.704

# %%
import joblib

# save model
joblib.dump(model, "model.pkl")
# Out:
# ['model.pkl']

# %%
model = joblib.load("model.pkl")

# %%
import pickle

with open("model.pkl", "wb") as f:
    pickle.dump(model, f)
